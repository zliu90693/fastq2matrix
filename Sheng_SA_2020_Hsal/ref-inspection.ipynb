# %% [markdown]
# **Depends on conda environment: fastq2matrix (see .env/fastq2matrix.yml)**

# %% [markdown]
# # 1
#
# determine which entry in the FASTA file is the mitochondrial.

# %%
from pyfaidx import Fasta

Hsal_fa = Fasta("./ref/Harpegnathos_saltator_gca003227715v2rs.Hsal_v8.5.dna.toplevel.fa")

# %%
for name in Hsal_fa.keys():
    print(name)
# Out:
# QANH01000094.1
# QANH01000039.1
# QANH01000059.1
# QANH01000694.1
# QANH01000026.1
# QANH01000009.1
# QANH01000203.1
# QANH01000296.1
# QANH01000017.1
# QANH01000052.1
# QANH01000844.1
# QANH01000256.1
# QANH01000183.1
# QANH01000046.1
# QANH01000220.1
# QANH01000120.1
# QANH01000048.1
# QANH01000116.1
# QANH01000055.1
# QANH01000172.1
# QANH01000209.1
# QANH01000092.1
# QANH01000057.1
# QANH01000382.1
# QANH01000468.1
# QANH01000204.1
# QANH01000061.1
# QANH01000129.1
# QANH01000102.1
# QANH01000498.1
# QANH01000177.1
# QANH01000404.1
# QANH01000005.1
# QANH01000097.1
# QANH01000708.1
# QANH01000034.1
# QANH01000226.1
# QANH01000060.1
# QANH01000385.1
# QANH01000789.1
# QANH01000008.1
# QANH01000140.1
# QANH01000072.1
# QANH01000175.1
# QANH01000846.1
# QANH01000539.1
# QANH01000779.1
# QANH01000019.1
# QANH01000087.1
# QANH01000084.1
# QANH01000002.1
# QANH01000011.1
# QANH01000040.1
# QANH01000214.1
# QANH01000016.1
# QANH01000437.1
# QANH01000599.1
# QANH01000594.1
# ...

# %%
# %%bash
#
# gppy txinfo -g "./ref/Harpegnathos_saltator_gca003227715v2rs.Hsal_v8.5.62.gtf" > ./metadata/Hsal_txinfo.tsv

# %%
import pandas as pd

Hsal_txinfo = pd.read_csv("./metadata/Hsal_txinfo.tsv", sep="\t")
Hsal_txinfo
# Out:
#                   tx_name       gene_id           chrom strand  nexon  tx_len  \
# 0          XM_011147203.3  LOC105186768  QANH01000094.1      -     19    7825
# 1          XM_025307715.1  LOC112590622  QANH01000094.1      -      1     949
# 2          XM_019840361.2  LOC105180861  QANH01000094.1      +      5     900
# 3          XM_011139205.2  LOC105182058  QANH01000094.1      +      4    5193
# 4          XM_011137161.3  LOC105180849  QANH01000094.1      -     14    2310
# ...                   ...           ...             ...    ...    ...     ...
# 29618      XM_025302762.1  LOC112589459  QANH01000513.1      +      1    1530
# 29619      XM_025302760.1  LOC112589457  QANH01000513.1      -      1    1068
# 29620      XM_025302761.1  LOC112589458  QANH01000513.1      +      1    3576
# 29621  LOC112590157_df_pt  LOC112590157  QANH01000734.1      +      7    1137
# 29622      XM_025305815.1  LOC105192082  QANH01000717.1      +      1    1132
#
# ...
